# %%
import pandas as pd
import mysql.connector
import os
import json

# %%
path_1 = 'D:/Project_2/pulse-master/data/aggregated/transaction/country/india/state/'

# %%
Agg_state_list=os.listdir(path_1) # in this we have the folders name means every state names

# %%
agg_trans = {'States':[], 'Years':[],'Quarter':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

# here we creating the dict

# %%
for i in Agg_state_list:
    p_i = path_1 + i + "/"
    agg_year = os.listdir(p_i)
    
    for year in agg_year:
        a_year = p_i + year + "/"
        agg_year_trans_j = os.listdir(a_year)
        
        for j in agg_year_trans_j:
            y_j = a_year + j
            with open(y_j,'r') as Data:
                file_d = json.load(Data)
           
            
            for z in file_d['data']['transactionData']:
                Name = z['name']
                Count = z['paymentInstruments'][0]['count']
                Amount = z['paymentInstruments'][0]['amount']
                agg_trans['Transaction_type'].append(Name)
                agg_trans['Transaction_count'].append(Count)
                agg_trans['Transaction_amount'].append(Amount)
                agg_trans['States'].append(i)
                agg_trans['Years'].append(year)
                agg_trans['Quarter'].append(int(j.strip('.json')))

# %%
Agg_trans = pd.DataFrame(agg_trans)

# %%
Agg_trans["States"] = Agg_trans["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Agg_trans["States"] = Agg_trans["States"].str.replace("-"," ")
Agg_trans["States"] = Agg_trans["States"].str.title()
Agg_trans['States'] = Agg_trans['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
Agg_trans
# Out:
#                  States Years  Quarter          Transaction_type  \
# 0     Andaman & Nicobar  2018        1  Recharge & bill payments
# 1     Andaman & Nicobar  2018        1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018        1         Merchant payments
# 3     Andaman & Nicobar  2018        1        Financial Services
# 4     Andaman & Nicobar  2018        1                    Others
# ...                 ...   ...      ...                       ...
# 4489        West Bengal  2024        1         Merchant payments
# 4490        West Bengal  2024        1     Peer-to-peer payments
# 4491        West Bengal  2024        1  Recharge & bill payments
# 4492        West Bengal  2024        1        Financial Services
# 4493        West Bengal  2024        1                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# ...

# %%
path_2 = 'D:/Project_2/pulse-master/data/aggregated/user/country/india/state/'

# %%
agg_user = {'States':[], 'Years':[],'Quarter':[],'Brands':[], 'Transaction_count':[], 'Percentage':[]}

# %%
agg_user_state = os.listdir(path_2)

# %%
for i in agg_user_state:
    p_states = path_2 + i + "/"
    agg_year = os.listdir(p_states)
    
    for year in agg_year:
        a_year = p_states + year + "/"
        agg_json_list = os.listdir(a_year)
        
        for j in agg_json_list:
            update_j = a_year + j
            with open(update_j,'r') as Data:
                file_d = json.load(Data)
                
                try:
                
                    for z in file_d['data']['usersByDevice']:
                        Brand = z['brand']
                        Count = z['count']
                        Percentage = z['percentage']
                        agg_user['Brands'].append(Brand)
                        agg_user['Transaction_count'].append(Count)
                        agg_user['Percentage'].append(Percentage)
                        agg_user['States'].append(i)
                        agg_user['Years'].append(year)
                        agg_user['Quarter'].append(int(j.strip('.json')))
                    
                except:
                    pass
                
Agg_User = pd.DataFrame(agg_user)

# %%
Agg_User["States"] = Agg_User["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Agg_User["States"] = Agg_User["States"].str.replace("-"," ")
Agg_User["States"] = Agg_User["States"].str.title()
Agg_User['States'] = Agg_User['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
Agg_User
# Out:
#                  States Years  Quarter   Brands  Transaction_count  Percentage
# 0     Andaman & Nicobar  2018        1   Xiaomi               1665    0.247033
# 1     Andaman & Nicobar  2018        1  Samsung               1445    0.214392
# 2     Andaman & Nicobar  2018        1     Vivo                982    0.145697
# 3     Andaman & Nicobar  2018        1     Oppo                501    0.074332
# 4     Andaman & Nicobar  2018        1  OnePlus                332    0.049258
# ...                 ...   ...      ...      ...                ...         ...
# 6727        West Bengal  2022        1   Lenovo             330017    0.015056
# 6728        West Bengal  2022        1  Infinix             284678    0.012987
# 6729        West Bengal  2022        1     Asus             280347    0.012790
# 6730        West Bengal  2022        1    Apple             277752    0.012671
# 6731        West Bengal  2022        1   Others            2196334    0.100199
#
# [6732 rows x 6 columns]

# %%
# Map

path_3 = 'D:/Project_2/pulse-master/data/map/transaction/hover/country/india/state/'

# %%
map_trans = {'States':[], 'Years':[],'Quarter':[],'District':[], 'Transaction_count':[], 'Amount':[]}

# %%
map_trans_states = os.listdir(path_3)

# %%
# map_trans_states

# %%
for i in map_trans_states:
    p_i = path_3 + i + "/"
    map_years = os.listdir(p_i)
    
    for year in map_years:
        a_year = p_i + year + "/"
        map_json_list = os.listdir(a_year)
        
        for j in map_json_list:
            update_j = a_year + j
            with open(update_j,'r') as Data:
                file_d = json.load(Data)
                
                for z in file_d['data']['hoverDataList']:
                    Name = z['name']
                    Count = z['metric'][0]['count']
                    Amount = z['metric'][0]['amount']
                    map_trans['District'].append(Name)
                    map_trans['Transaction_count'].append(Count)
                    map_trans['Amount'].append(Amount)
                    map_trans['States'].append(i)
                    map_trans['Years'].append(year)
                    map_trans['Quarter'].append(int(j.strip(".json")))
                    
                
Map_Trans = pd.DataFrame(map_trans)

# %%
Map_Trans["States"] = Map_Trans["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Map_Trans["States"] = Map_Trans["States"].str.replace("-"," ")
Map_Trans["States"] = Map_Trans["States"].str.title()
Map_Trans['States'] = Map_Trans['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
Map_Trans
# Out:
#                   States Years  Quarter                           District  \
# 0      Andaman & Nicobar  2018        1  north and middle andaman district
# 1      Andaman & Nicobar  2018        1             south andaman district
# 2      Andaman & Nicobar  2018        1                  nicobars district
# 3      Andaman & Nicobar  2018        2  north and middle andaman district
# 4      Andaman & Nicobar  2018        2             south andaman district
# ...                  ...   ...      ...                                ...
# 36587        West Bengal  2024        1                     nadia district
# 36588        West Bengal  2024        1                   birbhum district
# 36589        West Bengal  2024        1           purba medinipur district
# 36590        West Bengal  2024        1                    maldah district
# 36591        West Bengal  2024        1                 darjiling district
#
#        Transaction_count        Amount
# ...

# %%
path_4 = "D:/Project_2/pulse-master/data/map/user/hover/country/india/state/"

# %%
map_users = {'States':[], 'Years':[],'Quarter':[],'District':[], 'Registered_Users':[], 'App_Opens':[]}

# %%
map_user_states = os.listdir(path_4)

# %%
map_user_states
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
for i in map_user_states:
    p_i = path_4 + i + "/"
    map_user_year = os.listdir(p_i)
    
    for year in map_user_year:
        a_year = p_i + year + "/"
        map_json_list = os.listdir(a_year) 
        
        for j in map_json_list:
            update_j = a_year + j
            with open(update_j, 'r') as Data:
                file_d = json.load(Data)
                
                for z in file_d['data']['hoverData'].items():
                    District = z[0]
                    RegisteredUser = z[1]['registeredUsers']
                    AppOpens = z[1]['appOpens']
                    map_users['District'].append(District)
                    map_users['Registered_Users'].append(RegisteredUser)
                    map_users['App_Opens'].append(AppOpens)
                    map_users['States'].append(i)
                    map_users['Years'].append(year)
                    map_users['Quarter'].append(int(j.strip(".json")))
                    
    
Map_users = pd.DataFrame(map_users)

# %%
z
# Out:
# ('darjiling district', {'registeredUsers': 686254, 'appOpens': 31485682})

# %%
Map_users["States"] = Map_users["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Map_users["States"] = Map_users["States"].str.replace("-"," ")
Map_users["States"] = Map_users["States"].str.title()
Map_users['States'] = Map_users['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
Map_users
# Out:
#                   States Years  Quarter                           District  \
# 0      Andaman & Nicobar  2018        1  north and middle andaman district
# 1      Andaman & Nicobar  2018        1             south andaman district
# 2      Andaman & Nicobar  2018        1                  nicobars district
# 3      Andaman & Nicobar  2018        2  north and middle andaman district
# 4      Andaman & Nicobar  2018        2             south andaman district
# ...                  ...   ...      ...                                ...
# 18295        West Bengal  2024        1                     nadia district
# 18296        West Bengal  2024        1                   birbhum district
# 18297        West Bengal  2024        1           purba medinipur district
# 18298        West Bengal  2024        1                    maldah district
# 18299        West Bengal  2024        1                 darjiling district
#
#        Registered_Users  App_Opens
# ...

# %%
path_5 = 'D:/Project_2/pulse-master/data/top/transaction/country/india/state/'

# %%
top_trans = {'States':[], 'Years':[],'Quarter':[],'Pincode':[], 'Transaction_count':[], 'Transaction_amount':[]}

# %%
top_trans_states = os.listdir(path_5)

# %%
top_trans_states
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
for i in top_trans_states:
    p_i = path_5 + i + "/"
    top_trans_year = os.listdir(p_i)
    
    for year in top_trans_year:
        a_year = p_i + year + "/"
        top_trans_json_list = os.listdir(a_year)
        
        for j in top_trans_json_list:
            update_j = a_year + j 
            with open(update_j, 'r') as Data:
                file_d = json.load(Data)
                
                for z in file_d['data']['pincodes']:
                    Name = z['entityName']
                    Count = z['metric']['count']
                    Amount = z['metric']['amount']
                    top_trans['Pincode'].append(Name)
                    top_trans['Transaction_count'].append(Count)
                    top_trans['Transaction_amount'].append(Amount)
                    top_trans['States'].append(i)
                    top_trans['Years'].append(year)
                    top_trans['Quarter'].append(int(j.strip(".json")))

# %%
Top_trans = pd.DataFrame(top_trans)

# %%
Top_trans["States"] = Top_trans["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Top_trans["States"] = Top_trans["States"].str.replace("-"," ")
Top_trans["States"] = Top_trans["States"].str.title()
Top_trans['States'] = Top_trans['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
Top_trans
# Out:
#                  States Years  Quarter Pincode  Transaction_count  \
# 0     Andaman & Nicobar  2018        1  744101               1622
# 1     Andaman & Nicobar  2018        1  744103               1223
# 2     Andaman & Nicobar  2018        1  744102                969
# 3     Andaman & Nicobar  2018        1  744105                685
# 4     Andaman & Nicobar  2018        1  744104                340
# ...                 ...   ...      ...     ...                ...
# 8919        West Bengal  2024        1  732125            4490229
# 8920        West Bengal  2024        1  700006            4358390
# 8921        West Bengal  2024        1  700001            4321119
# 8922        West Bengal  2024        1  732201            4265219
# 8923        West Bengal  2024        1  742202            3985791
#
#       Transaction_amount
# 0           2.769298e+06
# 1           2.238042e+06
# 2           3.519060e+06
# 3           1.298561e+06
# 4           1.039715e+06
# ...

# %%
path_6 = 'D:/Project_2/pulse-master/data/top/user/country/india/state/'

# %%
top_users_states = os.listdir(path_6)

# %%
top_users = {'States':[], 'Years':[],'Quarter':[],'Pincode':[], 'Registere_Users':[]}

# %%
top_users_states
# Out:
# ['andaman-&-nicobar-islands',
#  'andhra-pradesh',
#  'arunachal-pradesh',
#  'assam',
#  'bihar',
#  'chandigarh',
#  'chhattisgarh',
#  'dadra-&-nagar-haveli-&-daman-&-diu',
#  'delhi',
#  'goa',
#  'gujarat',
#  'haryana',
#  'himachal-pradesh',
#  'jammu-&-kashmir',
#  'jharkhand',
#  'karnataka',
#  'kerala',
#  'ladakh',
#  'lakshadweep',
#  'madhya-pradesh',
#  'maharashtra',
#  'manipur',
#  'meghalaya',
#  'mizoram',
#  'nagaland',
#  'odisha',
#  'puducherry',
#  'punjab',
#  'rajasthan',
#  'sikkim',
#  'tamil-nadu',
#  'telangana',
#  'tripura',
#  'uttar-pradesh',
#  'uttarakhand',
#  'west-bengal']

# %%
for i in top_users_states:
    p_i = path_6 + i + "/"
    top_user_year = os.listdir(p_i)
    
    for year in top_user_year:
        a_year = p_i + year + "/"
        top_trans_json_list = os.listdir(a_year)
        
        for j in top_trans_json_list:
            update_j = a_year + j
            with open(update_j , 'r') as Data:
                file_d = json.load(Data)
                
                for z in file_d['data']['pincodes']:
                    Name = z['name']
                    Register_Users = z['registeredUsers']
                    top_users['Pincode'].append(Name)
                    top_users['Registere_Users'].append(Register_Users)
                    top_users['States'].append(i)
                    top_users['Years'].append(year)
                    top_users['Quarter'].append(int(j.strip(".json")))
                    
Top_Users = pd.DataFrame(top_users)

# %%
Top_Users["States"] = Top_Users["States"].str.replace("andaman-&-nicobar-islands","Andaman & Nicobar")
Top_Users["States"] = Top_Users["States"].str.replace("-"," ")
Top_Users["States"] = Top_Users["States"].str.title()
Top_Users['States'] = Top_Users['States'].str.replace("Dadra & Nagar Haveli & Daman & Diu", "Dadra and Nagar Haveli and Daman and Diu")

# %%
Top_Users
# Out:
#                  States Years  Quarter Pincode  Registere_Users
# 0     Andaman & Nicobar  2018        1  744103             1608
# 1     Andaman & Nicobar  2018        1  744101             1108
# 2     Andaman & Nicobar  2018        1  744105             1075
# 3     Andaman & Nicobar  2018        1  744102             1006
# 4     Andaman & Nicobar  2018        1  744104              272
# ...                 ...   ...      ...     ...              ...
# 8920        West Bengal  2024        1  700015           131676
# 8921        West Bengal  2024        1  742304           127917
# 8922        West Bengal  2024        1  721101           127891
# 8923        West Bengal  2024        1  700150           123919
# 8924        West Bengal  2024        1  700091           122985
#
# [8925 rows x 5 columns]

# %%
mydb = mysql.connector.connect(
  host ="localhost",
  user = "ananth",
  password = "ananth@2000"
)

# %%
print(mydb)

# %%
mycursor = mydb.cursor(buffered=True)

# %%
mycursor.execute("CREATE DATABASE phoneplus_db")

# %%
mycursor.execute("USE phoneplus_db")

# %%
# Aggregated transaction table creation
create_query_1 = '''CREATE TABLE IF NOT EXISTS aggregated_transaction (
                      States VARCHAR(255),
                      Years INT,
                      Quarter INT,
                      Transaction_type TEXT,
                      Transaction_count BIGINT,
                      Transaction_amount BIGINT
                    )'''

cursor.execute(create_query_1)

# Insert data into the aggregated_transaction table
for index, row in aggregated_transaction.iterrows():
    insert_query_1 = '''INSERT INTO aggregated_transaction 
                        (States, Years, Quarter, Transaction_type, Transaction_count, Transaction_amount)
                        VALUES (%s, %s, %s, %s, %s, %s)'''
    
    values = (
        row["States"],
        row["Years"],
        row["Quarter"],
        row["Transaction_type"],
        row["Transaction_count"],
        row["Transaction_amount"]
    )
    
    cursor.execute(insert_query_1, values)
    mydb.commit()

# %%
# Aggregated users table creation

create_query_2 = '''CREATE TABLE IF NOT EXISTS aggregated_user (
                      States VARCHAR(255),
                      Years INT(4),
                      Quarter INT,
                      Brands VARCHAR(150),
                      Transaction_count BIGINT,
                      Percentage float
                    )'''

cursor.execute(create_query_2)

# Insert data into the aggregated user table
for index, row in aggregated_user.iterrows():
    insert_query_2 = '''INSERT INTO aggregated_user 
                        (States, Years, Quarter, Brands, Transaction_count, Percentage)
                        VALUES (%s, %s, %s, %s, %s, %s)'''
    
    values = (
        row["States"],
        row["Years"],
        row["Quarter"],
        row["Brands"],
        row["Transaction_count"],
        row["Percentage"]
    )
    
    cursor.execute(insert_query_2, values)
    mydb.commit()

# %%
#map transaction table creation

create_query_3 = '''CREATE TABLE IF NOT EXISTS map_transaction (
                      States VARCHAR(255),
                      Years INT(4),
                      Quarter INT,
                      District VARCHAR(255),
                      Transaction_count BIGINT,
                      Transaction_amount float
                    )'''

cursor.execute(create_query_3)

# Insert data into the map_transaction table
for index, row in map_transaction.iterrows():
    insert_query_3 = '''INSERT INTO map_transaction 
                        (States, Years, Quarter, District, Transaction_count, Transaction_amount)
                        VALUES (%s, %s, %s, %s, %s, %s)'''
    
    values = (
        row["States"],
        row["Years"],
        row["Quarter"],
        row["District"],
        row["Transaction_count"],
        row["Transaction_amount"]
    )
    
    cursor.execute(insert_query_3, values)
    mydb.commit()

# %%
# #map Users table creation

create_query_4 = '''CREATE TABLE IF NOT EXISTS map_user (
                      States VARCHAR(255),
                      Years INT(4),
                      Quarter INT,
                      District VARCHAR(255),
                      Registered_Users BIGINT,
                      App_Opens BIGINT
                    )'''

cursor.execute(create_query_4)

# Insert data into the map user table
for index, row in map_user.iterrows():
    insert_query_4 = '''INSERT INTO map_user 
                        (States, Years, Quarter, District, Registered_Users, App_Opens)
                        VALUES (%s, %s, %s, %s, %s, %s)'''
    
    values = (
        row["States"],
        row["Years"],
        row["Quarter"],
        row["District"],
        row["Registered_Users"],
        row["App_Opens"]
    )
    
    cursor.execute(insert_query_4, values)
    mydb.commit()

# %%
# #Top transcation table creation

create_query_5 = '''CREATE TABLE IF NOT EXISTS top_transaction (
                      States VARCHAR(255),
                      Years INT(4),
                      Quarter INT,
                      Pincode INT(6),
                      Transaction_count BIGINT,
                      Transaction_amount BIGINT
                    )'''

cursor.execute(create_query_5)

# Insert data into the top_transaction table
for index, row in top_transaction.iterrows():
    insert_query_5 = '''INSERT INTO top_transaction 
                        (States, Years, Quarter, Pincode, Transaction_count, Transaction_amount)
                        VALUES (%s, %s, %s, %s, %s, %s)'''
    
    values = (
        row["States"],
        row["Years"],
        row["Quarter"],
        row["Pincode"],
        row["Transaction_count"],
        row["Transaction_amount"]
    )
    
    cursor.execute(insert_query_5, values)
    mydb.commit()

# %%
# #Top User table creation

create_query_6 = '''CREATE TABLE IF NOT EXISTS top_users (
                      States VARCHAR(255),
                      Years INT(4),
                      Quarter INT,
                      Pincode INT(6),
                      Registered_Users BIGINT
                    )'''

cursor.execute(create_query_6)

# Insert data into the Top user table
for index, row in top_users.iterrows():
    insert_query_6 = '''INSERT INTO top_users 
                        (States, Years, Quarter, Pincode, Registered_Users)
                        VALUES (%s, %s, %s, %s, %s)'''
    
    values = (
        row["States"],
        row["Years"],
        row["Quarter"],
        row["Pincode"],
        row["Registered_Users"]
    )
    
    cursor.execute(insert_query_6, values)
    mydb.commit()
